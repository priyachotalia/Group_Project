# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings; warnings.simplefilter('ignore')

# %%
sales_df=pd.read_csv("data/Sales_Data.csv")
sales_df.columns = ["Year", "Quarter", "LGA", "Dwelling Type", "First Quartile", "Second Quartile", 
                   "Third Quartile", "Mean Sales Price", "Sales Number", "Qtrly Median Change", 
                "Annly Median Change", "Qtrly Count Change", "Annly Count Change"]
sales_df.head(10)
# Out:
#      Year  Quarter                LGA Dwelling Type First Quartile  \
# 0  2018.0      4.0              Total         Total         290.00
# 1  2018.0      4.0              Total    Non Strata         294.00
# 2  2018.0      4.0              Total        Strata         275.00
# 3  2018.0      4.0             Albury         Total         240.00
# 4  2018.0      4.0             Albury    Non Strata         275.00
# 5  2018.0      4.0             Albury        Strata         160.00
# 6  2018.0      4.0  Armidale Regional         Total         275.00
# 7  2018.0      4.0  Armidale Regional    Non Strata         290.00
# 8  2018.0      4.0  Armidale Regional        Strata         175.00
# 9  2018.0      4.0            Ballina         Total         490.00
#
#   Second Quartile Third Quartile Mean Sales Price Sales Number  \
# 0          400.00         550.00           443.00      7916.00
# 1          411.00         560.00           452.00      6801.00
# ...

# %%
# %run scripts/Sales_Visualization.py

# %% [markdown]
# #### Clean Data
# * replaced "-" and "s" with NaN
# * fill NaN values with __bfill__ (Backward Filled Values)

# %%
sales_df.head(10)
# Out:
#    Year  Quarter                LGA Dwelling Type  First Quartile  \
# 0  2018        4              Total         Total             290
# 1  2018        4              Total    Non Strata             294
# 2  2018        4              Total        Strata             275
# 3  2018        4             Albury         Total             240
# 4  2018        4             Albury    Non Strata             275
# 5  2018        4             Albury        Strata             160
# 6  2018        4  Armidale Regional         Total             275
# 7  2018        4  Armidale Regional    Non Strata             290
# 8  2018        4  Armidale Regional        Strata             175
# 9  2018        4            Ballina         Total             490
#
#    Second Quartile  Third Quartile  Mean Sales Price  Sales Number  \
# 0              400             550               443          7916
# 1              411             560               452          6801
# ...

# %% [markdown]
# #### Top LGA with Highest Selling Price
# * new DataFrame was created to show the behaviour of the Selling Price per Quarter of the TOP LGA
# * LGAs were ranked based on the Renting Price, and the top 10 LGAs were graphed to show the increase and decrease in Selling Price per quarter

# %%
plt.figure(figsize=(15,10)) 
top_mean_df.transpose().plot()
plt.title('LGA with Highest Sales Price')
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xticks(rotation=-20)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14., 16.]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# #### LGA with Highest Number of Sales and it's Selling Price
# * plot LGA with highest number of sales compare it with the LGA's selling price
# * Selling price and sales per LGA correlation were also plotted. As illustrated the value of correlation between the Selling Price and Number of Sales is not that high
#
# ##### Analysis
# * The plots done proves that __Selling Price doesn't affect number of sales that much__, since the correlation between the columns are low, and the behavior of their line graphs are not uniformed

# %%
## plot Number of Sales
plt.figure(figsize=(15,10)) 
top_NB_df.transpose().plot()
plt.title('LGA with Highest Number of Sales')
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xticks(rotation=-20)

## Sales Price of LGAs with highest number of sales
plt.figure(figsize=(15,10))
top_nbmean_df.transpose().plot()
plt.title('LGA with Highest Number of Sales - Sales Price')
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xticks(rotation=-20)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14., 16.]),
#  <a list of 9 Text xticklabel objects>)

# %%
top_NB_df
# Out:
#                  2017.Q2  2017.Q3  2017.Q4  2018.Q1  2018.Q2  2018.Q3  2018.Q4
# LGA
# Yass Valley         1950     1546     1658     1509     1323     1447     1428
# Wollondilly          185      200      183      146      124      125      112
# Snowy Mountains      185      200      183      146      124      125      112
# Warringah            185      200      183      146      124      125      112
# Gosford              185      200      183      146      124      125      112
# Hawkesbury           254      273      206      200      137      190      154
# Holroyd              254      273      206      200      137      190      154
# Hornsby              551      457      485      374      284      406      365
# Liverpool            602      686      564      469      290      482      376
# Penrith              701      915      765      662      478      626      550

# %%
# %run scripts/PearsonValue.py

# %%
g = sns.pairplot(sales_df,
             vars = ['First Quartile', 'Second Quartile', 'Third Quartile', 'Mean Sales Price', 'Sales Number'],
             palette = 'husl',
             diag_kind = 'kde',
             diag_kws=dict(shade=True))

g.map_upper(corr)
g.map_lower(sns.regplot, line_kws = {'color':'red'})
plt.show()

# %% [markdown]
# #### Number of Sales per Year per Dwelling Type
# * as seen in the plot the gap between the number of sales of Strata and Non Strata is not that big, more people buy Non Strata properties compared to Strata

# %%
## Sales per year per dwelling type
plt.figure(figsize=(10,6)) 
 
sns.barplot(x = 'Year', 
            y = 'Count', 
            data = bond_count_df, 
            hue = 'Dwelling Type', 
            palette = 'husl',
            ci = None)
 
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('Sales per Year')
# Out:
# Text(0.5, 1.0, 'Sales per Year')
